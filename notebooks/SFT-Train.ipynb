# %%
# !git clone https://arthur900530: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@github.com/arthur900530/11667-project.git
# Out:
# Cloning into '11667-project'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 27 (delta 14), reused 21 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 13.50 KiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd "11667-project"
# Out:
# /content/11667-project

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install -r requirements.txt --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.5/465.5 kB 39.5 MB/s eta 0:00:00

# %%
# !pip install -q bitsandbytes>=0.41.0 --quiet

# %%
# 6ff923ca413ad8ec0030b9d48a974fdf3f8fd928
# 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

# %%
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: yuhangch0530 (yuhangch0530-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# # Qwen/Qwen2.5-Coder-3B

# %% [markdown]
# ## Config tunning

# %%
# Config 1: High rank
# !python finetune.py \
    --model_id "Qwen/Qwen2.5-Coder-3B" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 64 \
    --lora_alpha 128 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-qwen-lora-r64-a128" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "qwen-lora-r64-a128"
# Out:
# 2025-11-26 10:25:38.869298: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 10:25:38.888305: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764152738.910683    2511 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764152738.917521    2511 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Config 2: Mid rank
# !python finetune.py \
    --model_id "Qwen/Qwen2.5-Coder-3B" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 32 \
    --lora_alpha 64 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-qwen-lora-r32-a64" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "qwen-lora-r32-a64"
# Out:
# 2025-11-26 03:07:34.257803: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 03:07:34.276844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764126454.298721   28219 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764126454.305288   28219 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Config 3: Minimal rank
# !python finetune.py \
    --model_id "Qwen/Qwen2.5-Coder-3B" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 16 \
    --lora_alpha 32 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-qwen-lora-r16-a32" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "qwen-lora-r16-a32"
# Out:
# 2025-11-26 11:09:21.709887: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 11:09:21.727827: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764155361.749395   13840 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764155361.755926   13840 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Full training with best config

# %%
# Config 2: Mid rank
# !python finetune.py \
    --model_id "Qwen/Qwen2.5-Coder-3B" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 1500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 300 \
    --weight_decay 0.05 \
    --lora_r 32 \
    --lora_alpha 64 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-qwen-lora-r32-a64-full" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "qwen-lora-r32-a64-full" \
    --merge \
    --push_to_hub
# Out:
# 2025-11-26 15:52:31.205248: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 15:52:31.223971: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764172351.246220   40264 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764172351.253008   40264 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # deepseek-ai/deepseek-coder-1.3b-base

# %% [markdown]
# ## Config tunning

# %%
# Config 1: High rank
# !python finetune.py \
    --model_id "deepseek-ai/deepseek-coder-1.3b-base" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 64 \
    --lora_alpha 128 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-deepseek-lora-r64-a128" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "deepseek-lora-r64-a128"
# Out:
# 2025-11-27 12:26:03.507337: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 12:26:03.524464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764246363.545634    1801 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764246363.552075    1801 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Config 2: Mid rank
# !python finetune.py \
    --model_id "deepseek-ai/deepseek-coder-1.3b-base" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 32 \
    --lora_alpha 64 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-deepseek-lora-r32-a64" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "deepseek-lora-r32-a64"
# Out:
# 2025-11-27 13:03:03.049404: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 13:03:03.066357: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764248583.087475   11314 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764248583.093965   11314 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Config 3: Minimal rank
# !python finetune.py \
    --model_id "deepseek-ai/deepseek-coder-1.3b-base" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 50 \
    --weight_decay 0.05 \
    --lora_r 16 \
    --lora_alpha 32 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-deepseek-lora-r16-a32" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "deepseek-lora-r16-a32"
# Out:
# 2025-11-27 13:33:10.555319: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-27 13:33:10.572525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764250390.593587   18757 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764250390.600062   18757 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Full training with best config

# %%
# Config 1: High rank
# !python finetune.py \
    --model_id "deepseek-ai/deepseek-coder-1.3b-base" \
    --dataset_name "HuggingFaceH4/CodeAlpaca_20K" \
    --subset "default" \
    --split "train" \
    --max_steps 1500 \
    --micro_batch_size 4 \
    --gradient_accumulation_steps 4 \
    --learning_rate 2e-4 \
    --lr_scheduler_type "cosine" \
    --warmup_steps 300 \
    --weight_decay 0.05 \
    --lora_r 64 \
    --lora_alpha 128 \
    --lora_dropout 0.1 \
    --attention_dropout 0.1 \
    --do_eval \
    --eval_split "test" \
    --eval_steps 50 \
    --save_steps 250 \
    --save_total_limit 3 \
    --dataset_text_field "output" \
    --num_proc 4 \
    --seed 11667 \
    --output_dir "checkpoints/11667-deepseek-lora-r64-a128-full" \
    --use_wandb \
    --wandb_project "11667-experiments" \
    --wandb_run_name "deepseek-lora-r64-a128-full" \
    --merge \
    --push_to_hub
# Out:
# 2025-11-28 13:46:07.732597: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-28 13:46:07.749992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764337567.772106     785 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764337567.778765     785 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
